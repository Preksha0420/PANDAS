# %% [markdown]
# # <p style="text-align: center;"> Costs and Coverage of Diabetes Medications </p>
#
#
# ####  <p style="text-align: right;"> *Preksha Shah* </p>

# %% [markdown]
# ## <p style="text-align: center;"> Project Overview </p>
#
# ---
#
# **Analyzing ‘Medicare Part D Drugs’ Spending Trends And Implications in relation to Diabetes**

# %% [markdown]
# ### Problem Statement:
#
# Diabetes is a big problem for Medicare as it is a major prevalent chronic condition. According to an article by  CDC, *61% of diabetes costs are for adults aged 65 or older, which is mainly paid by Medicare(CDC, 2020)*. Hence, understanding the financial aspects of diabetes-related medications is crucial for the stakeholders at Medicare. By examining the costs associated with diabetic medications, we aim to offer valuable information to Medicare stakeholders, contributing to informed decision-making and program effectiveness.
#
# This project delves into Medicare Part D spending, specifically focusing on diabetic medications. The purpose of this analysis is to unveil spending patterns, identify outliers, and provide insights that can inform policy decisions, optimize resource allocation, and enhance care within the Medicare system.

# %% [markdown]
# ## <p style="text-align: center;"> Key Stakeholders </p>
#
# ---

# %% [markdown]
# #### The key stakeholders of our project are:
# - Medicare Program Mangers, Measure developers, Medicare Evidence Development & Coverage Advisory Committee (MEDCAC) and the administration at the federal level
#
# - Pharmaceutical compnaies: Disruptors, Innovators and Novel Companies
#
# - Policymakers and Government Officials

# %% [markdown]
# ## <p style="text-align: center;"> Objective Summary </p>
#
# ---

# %% [markdown]
# We are focusing on understanding the challenges posed by rising costs, outlier spending
# patterns, manufacturer influence, and long-term trends in diabetic medication spending
# within the Medicare Part D program. With an emphasis on diabetic drugs, the analysis of
# Medicare Part D spending data from 2017 to 2021 aims to offer actionable insights and
# suggestions that will improve the program's effectiveness, increase its financial
# sustainability, and raise beneficiary care standards. This project will give decision-makers
# the information they need to make wise choices and promote improvements to the
# Medicare program.

# %% [markdown]
# ## <p style="text-align: center;"> Project Description </p>
#
# ---

# %% [markdown]
# ### Comprehensive description
#
# - This Medicare Data Analysis Project aims to understand the complexities of medication spending under Medicare, focusing on diabetes medication. Leveraging a dataset with a range of data from brand and generic names of drugs to manufacturer details and financial metrics across 2017-2021, this project seeks to extract meaningful insights into spending patterns, identify outliers, and understand trends in diabetic expenses.
#
# - The project reveals significant proportion of diabetes medications in Medicare's total drug spending. It highlights the manufacturers contributing most significantly to the spending, especially through outlier analysis. Lastly, trends over the years indicate a fluctuation in spending, providing insights into Medicare's pharmaceutical expenses.
#
# - This Medicare Data Analysis Project provides an in-depth exploration of Medicare's Drug spending, while focusing on diabetes medications. Through data cleaning, analysis, and visualizations, this project offers a unique perspective on spending patterns, manufacturer impacts, and areas for policy adjustments within the Medicare infrastructure.
#
# ### Business Questions:
#
# - **How many diabetic medications are within the dataset and what the proportion of diabetic medications? How does it affect the spending of Medicare Part D Program?**
#
#     Diabetes Medication Analysis:
#      - The objective here is to identify and analyze the prevalence and financial impact of diabetes medications within the Medicare system. A key aspect of this analysis is to compare the spending on diabetes medications with the overall medication expenses.
#
#
# - **Can you identify diabetic medications with outlier spending patterns within the Medicare Part D program, which may have a significant impact on the program's budget?**
#
#     Outlier Detection and Impact Assessment:
#     - The objective here is to identify significant outliers in terms of spending across different manufacturers and to assess the financial impact of these on overall Medicare spending.
#
#
# - **Is there a relationship between the number of drug manufacturers for diabetic medications and drug spending within this specific category?**
#
#     Spending Trends Over Time:
#      - The objective here is to analyze the trends in medication spending from 2017-2021 with a focus on both overall and diabetic medications spending
#
#
# - **Examine the annual trends in Medicare Part D drug spending for diabetic medications from 2017 to 2021, including changes in average spending**
#
#     Manufacturer Analysis:
#      - The objective here is to evaluate the role and impact of different pharmaceutical manufacturers within the Medicare system, specifying those with contributing to outlier spending
#
#
# - **What are the actionable insights and recommendations for policymakers to optimize drug spending on diabetic medications within the Medicare Part D program?**
#
#
#
# #### Data Overview in Brief
# - The dataset is consists of various data types, inlcuding categorical(object), integer, and floating-point data. It includes columns like Brnd_Name, Gnrc_Name, Mftr_Name, alongside financial metrics for the years 2017 to 2021. The dataset initially consists of 13,751 rows and 46 columns, providing a comprehensive overview of Medicare's medication-related data.
#
# #### Methodology in Brief
# 1. **Data Cleaning and Preprocessing:**
#     We addressed missing values, filtering irrelevant data, and reducing the dataset to focus on key metrics. Also converting data types where necessary for accurate analysis.
#
# 2. ** Data Filtering for Diabetes Medication::**
#     We extracted a subset of data related to diabetes medications using a list of diabetic drugs. Also created a subset of data related to overall manufacturers.
#
# 3. **Outlier Detection:**
#     We used statistical methods, Interquartile Range (IQR) to identify outliers in spending data.
#
# 4. **Data Analysis and Visualization:**
#     After employing various analytical techniques to explore spending patterns. Then we utilized  visualization tools like bar charts, heatmaps, and line plots to illustrate findings.
#
#
# ### Motivation behind the project
# We came across several articles that showed the impact of diabetes on the US healthcare system and its role within medicare. This motivated us to further dig deep into the topic.
#
# - Diabetes is the most expensive chronic condition in our nation.(American Diabetes Association, 2018)
# - 1 out of every 4 dollar in US health care costs is spent on caring for people with diabetes.(American Diabetes Association, 2018)
# - 237 billion dollars is spent each year on direct medical costs and another 90 billion on reduced productivity.(American Diabetes Association, 2018)
# - 61% of diabetes costs are for adults aged 65 or older, which is mainly paid by Medicare.(American Diabetes Association, 2018)
# - Among Medicare beneficiaries aged 65 or older with type 2 diabetes, the estimated median costs associated with diabetes complications is 5,876 dollars per person each year.(Wang et al., 2022)
# - 48% to 64% of lifetime medical costs for a person with diabetes are for complications related to diabetes, such as heart disease and stroke.(Zhou et al., 2013)
#
# The motivation behind this project to enhance the efficiency and effectiveness of healthcare spending, particularly for a critical and growing area like diabetes treatment. By using data analysis, the project aims to contribute to better health outcomes, a more sustainable healtcare policy, and a more transparent and accountable healthcare system.

# %% [markdown]
# ## <p style="text-align: center;"> Methodology </p>
#
# ---

# %% [markdown]
# ### Metadata
#
# - Brnd_Name: Brand name, Trademark name that is filed
# - Gnrc_Name: Generic Name of drug, chemical ingredient of a drug
# - Tot_Mftr: Total Manufacturers of the drug
# - Mftr_Name: Name of manufacturers.
# - Tot_Spndng_Year: Aggregate drug spending for the Medicare Part D program during the benefit year.
# - Tot_Dsg_Unts_Year: The sum of the dosage units of medication dispensed across the calendar year
# - Tot_Clms_Year: Number of prescription fills for each drug.
# - Tot_Benes_Year: Number of Part D beneficiaries utilizing the drug during the benefit year.
# - Avg_Spnd_Per_Dsg_Unt_Wghtd_Year: Medicare Part D drug spendingdivided by the number of dosage units, which is weighted by the proportion of total claims.
# - Avg_Spnd_Per_Clm_Year: Part D drug spending divided by the number of prescription fills.
# - Avg_Spnd_Per_Bene_Year: Total Part D drug spending divided by the number of unique beneficiaries utilizing the drug during the benefit year.
# - Outlier_Flag_Year: Yearly outlier flag variable, which is set to “1” when a drug’s Average Spending per Dosage Unit is substantially impacted by outlier records in a given year.
# - Chg_Avg_Spnd_Per_Dsg_Unt_20_21: The percent change in average spending per dosage unit from the prior year.
# - CAGR_Avg_Spnd_Per_Dsg_Unt_17_21: The constant average change in spending per dosage unit over the most recent five years of data availability, calculated using the compound annual growth rate (CAGR).
#
# Note: For variable ending in _Year, these represent columns with range of year from 2017-2021.

# %% [markdown]
# ### Data Overview and Data Cleaning
#
# #### Object Type (String): Assumptions are included in parenthesis
# - Characteristics: Represents text or mixed numeric and non-numeric values
# - Columns: Includes categorical or descriptive data such as 'Brnd_Name'(Brand Name), 'Gnrc_Name'(Generic Name), and 'Mftr_name'(Manufacturer Name)
# - Usage: These columns are primarily used for grouping, filtering, and identifying unique entries in the dataset
#
# #### Integer (int64): Assumptions are included in parenthesis
# - Characteristics: Contain integer values without decimal points
# - Columns: Includes columns like Tot_Mftr (Total Manufacturer), Tot_Clms_2021 (Total Claims in 2021), and Outlier_Flag_2021 which are expected to have whole number values.
# - Usage: These columns are primarily used for quantitative analyses
#
# #### Floating Point (float64): Assumptions are included in parenthesis
# - Characteristics: Represents numerica values with decimals
# - Columns: Includes columns like Tot_Spndng_2017 (Total Spending in 2017), Tot_Spndng_2018 (Total Spending in 2018),  Tot_Spndng_2019 (Total Spending in 2019), Tot_Spndng_2020 (Total Spending in 2020) and Tot_Spndng_2021 (Total Spending in 2021)
# - Usage: These columns are primarily used for financial analysis, allowing for averages and proportional analysis
#
# #### Reading and Initial Data Assessment
# - Dataset Loading: Medicare dataset was loaded into a pandas DataFrame.
# - ** Intial Size and Description: **
#     - Dataset initially contained 13,751 rows and 46 columns
#     - 'describe()' function was used to get a summart of the dataset which provided count, mean, standard deviation, min, and max values across columns
#
# #### Data Types and Structure:
# - Data Types Assessment: The data types ('dtypes') of each column were checked to understand the structure and type, either numeric or object, of data in each column
# - Column Inspection: 'columns' attribute was used to review all column names, ensuring proper understanding and alignment with our objectives
#
# #### Handling Null Values:
# - Null Value Indetification: the 'isnull().sum()' function was used to identify columns with missing values
# - Strategic Handling of Nulls: Since the focus was on Spending data of Diabetic Drugs rows with null values in unrealted variables were not dropped immediately. Cleaning was decided to be done on a case-bye-case basis
#
# #### Data Filtering and Specific Dataset Creation:
# - Filtering Out "Overall" Metrics: Rows with 'Overall' in the 'Mftr_Name' column was filtered out as they did not represent specific manufacturer data
# - Creation of a Diabetes-specific Dataset:
#     - List of diabetes medication names was defined
#     - Dataset was filtered to include only rows where either 'Brnd_Name' or 'Gnrc_Name' matched the diabetes medication names, using regular expressions
#
#
# #### Data Reduction and Optimization:
# - Column Reduction:
#     - List of relevant columns was identified to focus on the key metrics
#     - Dataset was then reduced to include only these selected columns
# - Splitting Dataset Based on Manufacturer:
#     - Diabetes dataset was split into two based on the 'Mftr_Name' column (First dataset was for 'Overall' and Second for the other manufacturers)
#
#
# ```python
# # list of columns to keep
# columns_to_keep = ['Brnd_Name', 'Gnrc_Name', 'Tot_Mftr', 'Mftr_Name', 'Tot_Spndng_2017', 'Tot_Spndng_2018', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']
#
# # keep only the specified columns
# medicare = medicare[columns_to_keep]
# diabetic_medications = diabetic_medications[columns_to_keep]
# ```

# %% [markdown]
# ### Data Analysis Methods and Assumptions Used

# %% [markdown]
# #### Outlier Detection and Analysis:
# - Outlier Identification Method:
#     - A function was created to identify outliers using the Interquartile Range (IQR) Method.
#     - This method was applied to specific columns like 'Tot_Spending_2021'
# - Analysis of Outliers:
#     - Outliers were anlyzed to understand their impact on total spending
#     - Top outliers manufacturers were identified and visualized using bar charts and heatmaps

# %% [markdown]
# # function to identify outliers, credit to Dr.Neha Bhomia whose code is used as a backbone for this.
# def find_and_display_outliers(dataframe, column_name, additional_column):
#     """
#     This function finds and displays the outliers in a specific column of a dataframe using the IQR method.
#     params:
#         - dataframe: pandas DataFrame
#         - column_name: Name of the column for which outliers are to be calculated
#         - additional_column: Additional column to be displayed along with 'Gnrc_Name' and 'Tot_Spndng_2017'
#     returns:
#         - A DataFrame containing 'Gnrc_Name', 'Tot_Spndng_2017', and the specified additional column for rows with outliers
#     """
#     # extracting the specified column
#     pd_object = dataframe[column_name]
#
#     # checking if the column contains numerical data
#     if not pd.api.types.is_numeric_dtype(pd_object):
#         raise ValueError(f"The column '{column_name}' does not contain numerical data.")
#
#     # calculating Q1 (also known as 25th percentile)
#     q1 = pd_object.quantile(0.25)
#
#     # calculating Q3 (also known as 75th percentile)
#     q3 = pd_object.quantile(0.75)
#
#     # calculating the IQR
#     iqr = q3 - q1
#
#     # calculating the upper and lower bounds
#     upper = q3 + 1.5 * iqr
#     lower = q1 - 1.5 * iqr
#
#     # finding the outliers
#     outliers_mask = (pd_object < lower) | (pd_object > upper)
#
#     # extracting the rows with outliers
#     outliers_df = dataframe[outliers_mask][['Gnrc_Name', column_name, additional_column]]
#
#     return outliers_df

# %% [markdown]
# #### Grouped Analysis:
# - Grouping and Summarization:
#     - Data was grouped by manufacturer count and total spending for each year was summarized
#     - Provided insight into spending across different manufacturers over the years as well as any trends or patterns
#
#
# ```python
# # grouping the data and adding up the spending by Manufacturer name
# outliers_result = outliers_result.groupby('Mftr_Name')['Tot_Spndng_2021'].sum()
# # sort the data
# outliers_result = outliers_result.sort_values(ascending=False)
# ```
#
# #### Comparative Analysis:
# - Average Spending Analysis:
#     - Average spending for diabetic drugs and the original dataset was calculated for each year
#     - Comparative trends were analyzed and visualized to understand how diabetic drug spendign compared to overall drug spending
#
#
# ```python
# # calculating the average spending for each year for diabetic drugs using regex
# avg_spending_diabetic = overall_df.filter(regex='Tot_Spndng_').mean()
#
# # calculating the average spending for each year for the original dataset using regex
# avg_spending_original = medicare2.filter(regex='Tot_Spndng_').mean()
#
# avg_spending_diabetic/avg_spending_original * 100
# ```

# %% [markdown]
# #### Visualization:
# - Libraries Used for Visualizations:
#     - seaborn
#     - matplotlib
# - Various visualizations were used throughout the process, this included line plots, bar charts, and heatmaps to effectively communicate findings and trends that were found throughout the analysis of the medicare data.
#
#
#
# ```python
# # plotting the data
# plt.figure(figsize=(10, 5))
# plt.plot(avg_spending_diabetic.index.str[-4:], avg_spending_diabetic, label='Diabetic Drugs')
# plt.plot(avg_spending_original.index.str[-4:], avg_spending_original, label='Original Dataset')
# plt.title('Average Spending Trends for Diabetic Drugs vs. Original Dataset (2017-2021)')
# plt.xlabel('Year')
# plt.ylabel('Average Spending')
# plt.legend()
# plt.grid()
# plt.show()
# ```
#
#
# ```python
# # making a heatmap with grid lines
# plt.figure(figsize=(15, 10))
# sns.heatmap(heatmap_data, cmap='plasma', fmt=".2e", linewidths=1, linecolor='white', cbar_kws={'label': 'Total Spending'})
# plt.title('Total Outlier Spending in 2021 - Diabetic Medications')
# plt.xlabel('Manufacturer Name')
# plt.ylabel('Generic Name')
# plt.show()
# ```
#
# #### Other Methods:
#
# - We also used pivot method, to get the data represented according to our need.
#
#
# ```python
# # pivoting the data for the heatmap
# heatmap_data = outlier_result.pivot('Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2021')
# ```

# %% [markdown]
# ## <p style="text-align: center;"> Visualizations and Conclusions </p>
#
# ---

# %% [markdown]
# The analysis provided us with great understanding of the position of diabetes drugs within the Medicare Part D drug Spending dataset and its financial dynamic.
#
# ### An ordered review of the conclusions reached on inferring our Analysis and Visualization is as follows:
#
# #### **Objective 1:**
#
# ![Annual Trends in Medicare Spending for Diabetic Medications (2017-2021)](AnnualTrends_DiabeticMedications.PNG "Objective 1")
# At least one out of 29 generic medications is diabetes medication. This is a significant number considering the dataset represents medications for all diseases covered by Part D drugs.
#
# #### **Objective 2:**
#
# ![Top 5 Manufacturers - Total Spending in 2021](Top5Manufacturers_spending2021.PNG "Objective 2.1")
#
# ![Spending Distribution Across Manufacturers for Top Generic Drugs in 2021](SpendingDistributionTop5_2021.PNG "Objective 2.2")
#
# ![Top Manufacturers vs Generic Names - Total Spending in 2021](TopManufacturersVSGenericNames_spending2021.PNG "Objective 2.3")
#
# ![Total Outlier Spending in 2021 - Diabetic Medications](TotalOutlierSpending2021.PNG "Objective 2.4")
#
#
#
# As we see above, **97%** of the total spending is on the outliers and hence, this needs to be controlled and checked.
# Further looking into reasons behind this, as we can see the **top 5 companies** that are responsible for outlier spending patterns also have a monopoly in the drugs they create and hence charge exceptionally high amounts. This is an opportunity for new pharma companies or pharmaceutical companies finding an opportunity to dive into.
# Also, Medicare needs to negotiate its terms with these manufacturers in ways using policy reform, negotiating the prices, and leveraging the last customer base they have.
# Also, the companies that manufacture outlier drugs at lower costs and fall in the normal range, can be looked into for negotiation and providing them with better incentives.
#
# #### **Objective 3:**
#
# ![Total Drug Spending vs. Number of Manufacturers (2017-2021)](TotalDrugSpendingVSManufacturers_2017_2021.PNG "Objective 3")
#
#
# Based on the visualization, it is evident that drugs with manufacturers between 0-3 have higher total spending. Drugs with more than 3 manufacturers have comparatively minimal spending.
#
#
# #### **Objective 4:**
#
# ![Average Spending Trends for Diabetic Drugs vs. Original Dataset (2017-2021)](AverageSpendingDiabeticVSOriginal_2017_2021.PNG "Objective 4.1")
#
# ![Comparison of Average Spending Trends (2017-2021)](ComparisonAverageSpendingTrends_2017_2021.PNG "Objective 4.2")
#
#
#
# We can interpret from the chart that the average spending for the original dataset increases, the average spending for diabetes medications has decreased over time.
# However, it is still significant considering that **although they just form 3.45% of the all the prescription drugs, the average spending still is 135(2017)-107(2021) percent more than that of the overall average spending**.

# %% [markdown]
# ## <p style="text-align: center;"> Ethical Considerations and Project Limitations</p>
#
# ---

# %% [markdown]
# ### Ethical considerations
#
# #### Ethical Standards within the project
#
# - Clearly documenting data sources and methodologies to **maintain
# transparency and trust**.
# - Ensuring patient data is **anonymized and protected**.
# - **Avoiding any bias** in the analysis that could impact policy decisions unfairly.
#
# #### Ethical Issues out of hand:
#
# - Potential biases in the original data collected by the Medicare Part D Program. This could be based on gender, region, race, etc.
#
# ### Risk Assessment
#
# #### Risks:
# - The primary risk in our project is potential biases in the original dataset collected by Medicare Part D Program. These biases could be based on different factors such as gender, region, race, etc.
# - Such biases in the data can significantly affect the accuract and generalizability of our findings. If certain groups are overrepresented or underrepresented in the dataset, our conclusions drawn from the analysis may not accurately reflect the general population.
#
#
# #### Risk Mitigation:
# - Clearly documenting the potential limitations and biases in the data and discussing how they might affect the conclusions.
# - Regularly updating the analysis with new data as it becomes available and monitoring for changes that might suggest previous biases are no longer present or any new biases may have emerged.
#
#
# ### Project Limitations
#
# The dataset represents only a subset of Medicare beneficiaries enrolled in Part D.
# - All of the spending data for a drug that has fewer than 11 claims is redacted.
# - When the drug information is based on more than 11 claims but less than 11
# unique beneficiaries, Total Beneficiaries are redacted since that measure uses the
# unique beneficiary count as its denominator.
# - The analysis is limited to the data available from 2017 to 2021; does not account
# for more recent data.
# - Does not consider the broader context of healthcare policy changes beyond the
# scope of Medicare Part D.
# - The Part D spending metrics do not reflect any manufacturers’ rebates or other
# price concessions as CMS is prohibited from publicly disclosing such information.

# %% [markdown]
# ## <p style="text-align: center;"> Conclusions </p>

# %% [markdown]
# #### Below we answer the final business questions along with Conclusions for the project as a whole:
#
# Actionable Insights
# 1. **High Proportion of Diabetes Medication:**
#     - Diabetes medications form a significant part of the Medicare Part D portfolio, about 3.5% of the portfolio is related to diabetes medication, indicating a high prevalence of diabetes among beneficiaries.
# 2. **Outlier Spending on Specific Drugs:**
#     - A small number of drugs and manufacturers are responsible for a disproportionately large share of spending, which can be due to a lack of competition or patented formulations.
# 3. **Trend of Increasing Spending:**
#     - Overall spending on diabetic medications has been increasing from 2017-2021.
# 4. **Impact of Monopolistic Practices:**
#     - Certain manufacturers with monopolies over specific drugs tend to increase prices, which contributes to the outlier spending
#
# ### Recommendations for Stakeholders
# 1. **Negotiation of Drug Prices:**
#     - We recommend Medicare negotiate directly with drug manufacturers to secure better prices, specifically for high-cost diabetic medications that are outliers in terms of spending cost.
# 2. **Encourage Generic and Biosimilar Drug Use:**
#     - We recommend Medicare to promote the use of generic and biosimilar versions of expensive diabetic medications to provide a more cost-effective alternative without compromising treatment quality.
# 3. **Implement Price Caps:**
#     - We recommend setting price caps for essential diabetic medications to prevent price gouging and ensure affordability for Medicare beneficiaries.
# 4. **Supporting Pharmaceutical Competition:**
#     - We recommend encouraging competition in the pharmaceutical market, in particular for the drugs that are currently monopolized, which will lower prices and increase access to those diabetic medications.
#
# ### Final Thoughts
#
# By implementing these recommendations, stakeholders can take steps towards optimizing drug spending in the Medicare Part D program, particularly medications concerning diabetes. These actions can lead to more sustainable healthcare spending, improved access to necessary medications for Medicare beneficiaries, and overall better health outcomes for individuals with diabetes.

# %% [markdown]
# ## <p style="text-align: center;"> Future Work </p>

# %% [markdown]
# ### Additional Data Collection Requirements
# This analysis can be further explored by merging it with an existing dataset on Demographics and Utilization in Medicare. It can be converted to a dashboard, that helps assess the disparities in healthcare accessibibility in regards to Medicare. Moreover, a heatmap over geographical fragments can help in fnding gaps and oppotunities to serve the Medicare population.
#
# ### Future Work Prospect and Application
#
# #### Medicare
#
# - Reprodiciblity
#   - For eg. Use it for analysis of medicaid drug datasets.
#   - Can use the analysis tool with recent data sets to help improve **real time decisions** made regarding coverage thereby improving healthcare access and cost savings.
# - Hypothetically can involve adjusting Medicare Part D coverage for diabetic medications based on the analysis and use it to **negotiate prices** with the pharmaceutical companies.
# - Potential to **integrate with the dashboard** that the CMS maintains.
#
# #### Pharmaeutical Companies
#
# - The analysis can also be used by pharmaceutical companies for their future projects and **finding potential areas of research for drugs with limited manufacturers and higher spending**.
# - **Key-Partnerships** for companies who provide drugs at lower costs in comparison to the market.
#
# #### Policmakers
#
# - Can be used to **inform Medicare policy decisions** related to diabetic medications by the government agencies.
# - Policy reforms to **cap the costs** for diabetes based medications.
# - Monitor and manage **provider prescription practices** to foster transition to **Value-Based Care**.
# - Reforms on current **regulatory barriers that limit generic and biosimilar development**.
# - Overall improvement of healthcare access and **reduce burden on US healthcare system**.
#
# #### Beneficiaries/Patients
#
# - Low values, as they have no power over costs, are not the payer.
# - They can use the interpretation to make informed decisions on pushing policy reforms and bills, election choices as well as selecting insurance plans.

# %% [markdown]
# ## <p style="text-align: center;"> Appendix </p>

# %% [markdown]
# ### Supplementary material
#
# Link to dataset: https://data.cms.gov/summary-statistics-on-use-and-payments/medicare-medicaid-spending-by-drug/medicare-part-d-spending-by-drug
#
# Medicare Coverage of Diabetes Supplies, Services, & Prevention Programs - https://www.medicare.gov/publications/11022-le-medicare-coverage-of-diabetes.pdf

# %% [markdown]
# ### Code Documentation
#
#
# ```python
# # importing the required libraries
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
#
# ```python
# # reading in the dataset
# medicare = pd.read_csv('Data/Medicare.csv')
# ```
#
#
# ```python
# # size of the raw dataset
# medicare.shape
# ```
#
#
#
#
#     (13751, 46)
#
#
#
#
# ```python
# # summary of what dataset looks like
# medicare.describe()
# ```
#
#
#
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tot_Mftr</th>
#       <th>Tot_Spndng_2017</th>
#       <th>Tot_Dsg_Unts_2017</th>
#       <th>Tot_Clms_2017</th>
#       <th>Tot_Benes_2017</th>
#       <th>Avg_Spnd_Per_Dsg_Unt_Wghtd_2017</th>
#       <th>Avg_Spnd_Per_Clm_2017</th>
#       <th>Avg_Spnd_Per_Bene_2017</th>
#       <th>Outlier_Flag_2017</th>
#       <th>Tot_Spndng_2018</th>
#       <th>...</th>
#       <th>Tot_Spndng_2021</th>
#       <th>Tot_Dsg_Unts_2021</th>
#       <th>Tot_Clms_2021</th>
#       <th>Tot_Benes_2021</th>
#       <th>Avg_Spnd_Per_Dsg_Unt_Wghtd_2021</th>
#       <th>Avg_Spnd_Per_Clm_2021</th>
#       <th>Avg_Spnd_Per_Bene_2021</th>
#       <th>Outlier_Flag_2021</th>
#       <th>Chg_Avg_Spnd_Per_Dsg_Unt_20_21</th>
#       <th>CAGR_Avg_Spnd_Per_Dsg_Unt_17_21</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>13751.000000</td>
#       <td>9.357000e+03</td>
#       <td>9.357000e+03</td>
#       <td>9.357000e+03</td>
#       <td>9.289000e+03</td>
#       <td>9357.000000</td>
#       <td>9357.000000</td>
#       <td>9.175000e+03</td>
#       <td>9357.000000</td>
#       <td>1.037100e+04</td>
#       <td>...</td>
#       <td>1.375100e+04</td>
#       <td>1.375100e+04</td>
#       <td>1.375100e+04</td>
#       <td>1.300300e+04</td>
#       <td>13751.000000</td>
#       <td>13751.000000</td>
#       <td>1.300300e+04</td>
#       <td>13751.000000</td>
#       <td>12561.000000</td>
#       <td>12665.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1.481347</td>
#       <td>3.202212e+07</td>
#       <td>2.107802e+07</td>
#       <td>2.981529e+05</td>
#       <td>8.990329e+04</td>
#       <td>129.745891</td>
#       <td>1150.936694</td>
#       <td>5.924631e+03</td>
#       <td>0.069680</td>
#       <td>3.198567e+07</td>
#       <td>...</td>
#       <td>3.137348e+07</td>
#       <td>1.664438e+07</td>
#       <td>2.182277e+05</td>
#       <td>7.190565e+04</td>
#       <td>187.152264</td>
#       <td>1710.708555</td>
#       <td>8.540983e+03</td>
#       <td>0.125445</td>
#       <td>0.018722</td>
#       <td>-0.000125</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>2.325870</td>
#       <td>1.598840e+08</td>
#       <td>1.139396e+08</td>
#       <td>1.521367e+06</td>
#       <td>3.975383e+05</td>
#       <td>1229.392323</td>
#       <td>5172.366970</td>
#       <td>3.757367e+04</td>
#       <td>0.254621</td>
#       <td>1.734824e+08</td>
#       <td>...</td>
#       <td>2.439032e+08</td>
#       <td>1.126016e+08</td>
#       <td>1.370878e+06</td>
#       <td>3.782405e+05</td>
#       <td>1549.614977</td>
#       <td>8068.923486</td>
#       <td>4.956496e+04</td>
#       <td>0.331235</td>
#       <td>0.423349</td>
#       <td>0.168335</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#       <td>3.202000e+01</td>
#       <td>1.150000e+01</td>
#       <td>1.100000e+01</td>
#       <td>1.100000e+01</td>
#       <td>0.000697</td>
#       <td>0.087388</td>
#       <td>2.181074e-01</td>
#       <td>0.000000</td>
#       <td>5.438000e+01</td>
#       <td>...</td>
#       <td>1.712000e+01</td>
#       <td>1.050000e+01</td>
#       <td>1.100000e+01</td>
#       <td>1.100000e+01</td>
#       <td>0.000216</td>
#       <td>0.035966</td>
#       <td>9.945269e-02</td>
#       <td>0.000000</td>
#       <td>-0.977451</td>
#       <td>-0.947429</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.000000</td>
#       <td>1.056260e+05</td>
#       <td>4.092200e+04</td>
#       <td>8.610000e+02</td>
#       <td>3.450000e+02</td>
#       <td>0.406413</td>
#       <td>25.043320</td>
#       <td>6.596498e+01</td>
#       <td>0.000000</td>
#       <td>9.760332e+04</td>
#       <td>...</td>
#       <td>3.843770e+04</td>
#       <td>1.167850e+04</td>
#       <td>2.600000e+02</td>
#       <td>1.390000e+02</td>
#       <td>0.479254</td>
#       <td>30.806078</td>
#       <td>7.542202e+01</td>
#       <td>0.000000</td>
#       <td>-0.066324</td>
#       <td>-0.055639</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1.000000</td>
#       <td>1.433509e+06</td>
#       <td>4.322070e+05</td>
#       <td>8.073000e+03</td>
#       <td>2.633000e+03</td>
#       <td>1.752040</td>
#       <td>95.143960</td>
#       <td>2.403992e+02</td>
#       <td>0.000000</td>
#       <td>1.284906e+06</td>
#       <td>...</td>
#       <td>6.739760e+05</td>
#       <td>1.545117e+05</td>
#       <td>2.919000e+03</td>
#       <td>1.265000e+03</td>
#       <td>2.086887</td>
#       <td>111.082237</td>
#       <td>2.767936e+02</td>
#       <td>0.000000</td>
#       <td>0.008377</td>
#       <td>0.005116</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.000000</td>
#       <td>1.009581e+07</td>
#       <td>4.817027e+06</td>
#       <td>8.387300e+04</td>
#       <td>2.789600e+04</td>
#       <td>9.690583</td>
#       <td>414.860960</td>
#       <td>1.293727e+03</td>
#       <td>0.000000</td>
#       <td>9.322213e+06</td>
#       <td>...</td>
#       <td>6.419595e+06</td>
#       <td>2.096034e+06</td>
#       <td>3.484750e+04</td>
#       <td>1.350150e+04</td>
#       <td>13.947308</td>
#       <td>569.744789</td>
#       <td>1.700673e+03</td>
#       <td>0.000000</td>
#       <td>0.063505</td>
#       <td>0.049994</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>40.000000</td>
#       <td>3.311187e+09</td>
#       <td>3.458943e+09</td>
#       <td>4.854712e+07</td>
#       <td>1.064562e+07</td>
#       <td>38341.547448</td>
#       <td>142105.950320</td>
#       <td>1.284949e+06</td>
#       <td>1.000000</td>
#       <td>4.991813e+09</td>
#       <td>...</td>
#       <td>1.257515e+10</td>
#       <td>4.338735e+09</td>
#       <td>6.110057e+07</td>
#       <td>1.495589e+07</td>
#       <td>42825.007606</td>
#       <td>304487.484000</td>
#       <td>1.561519e+06</td>
#       <td>1.000000</td>
#       <td>19.449818</td>
#       <td>3.747398</td>
#     </tr>
#   </tbody>
# </table>
# <p>8 rows × 43 columns</p>
# </div>
#
#
#
#
# ```python
# # datatypes of the raw data
# medicare.dtypes
# ```
#
#
#
#
#     Brnd_Name                           object
#     Gnrc_Name                           object
#     Tot_Mftr                             int64
#     Mftr_Name                           object
#     Tot_Spndng_2017                    float64
#     Tot_Dsg_Unts_2017                  float64
#     Tot_Clms_2017                      float64
#     Tot_Benes_2017                     float64
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    float64
#     Avg_Spnd_Per_Clm_2017              float64
#     Avg_Spnd_Per_Bene_2017             float64
#     Outlier_Flag_2017                  float64
#     Tot_Spndng_2018                    float64
#     Tot_Dsg_Unts_2018                  float64
#     Tot_Clms_2018                      float64
#     Tot_Benes_2018                     float64
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    float64
#     Avg_Spnd_Per_Clm_2018              float64
#     Avg_Spnd_Per_Bene_2018             float64
#     Outlier_Flag_2018                  float64
#     Tot_Spndng_2019                    float64
#     Tot_Dsg_Unts_2019                  float64
#     Tot_Clms_2019                      float64
#     Tot_Benes_2019                     float64
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    float64
#     Avg_Spnd_Per_Clm_2019              float64
#     Avg_Spnd_Per_Bene_2019             float64
#     Outlier_Flag_2019                  float64
#     Tot_Spndng_2020                    float64
#     Tot_Dsg_Unts_2020                  float64
#     Tot_Clms_2020                      float64
#     Tot_Benes_2020                     float64
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2020    float64
#     Avg_Spnd_Per_Clm_2020              float64
#     Avg_Spnd_Per_Bene_2020             float64
#     Outlier_Flag_2020                  float64
#     Tot_Spndng_2021                    float64
#     Tot_Dsg_Unts_2021                  float64
#     Tot_Clms_2021                        int64
#     Tot_Benes_2021                     float64
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2021    float64
#     Avg_Spnd_Per_Clm_2021              float64
#     Avg_Spnd_Per_Bene_2021             float64
#     Outlier_Flag_2021                    int64
#     Chg_Avg_Spnd_Per_Dsg_Unt_20_21     float64
#     CAGR_Avg_Spnd_Per_Dsg_Unt_17_21    float64
#     dtype: object
#
#
#
#
# ```python
# medicare.columns
# ```
#
#
#
#
#     Index(['Brnd_Name', 'Gnrc_Name', 'Tot_Mftr', 'Mftr_Name', 'Tot_Spndng_2017',
#            'Tot_Dsg_Unts_2017', 'Tot_Clms_2017', 'Tot_Benes_2017',
#            'Avg_Spnd_Per_Dsg_Unt_Wghtd_2017', 'Avg_Spnd_Per_Clm_2017',
#            'Avg_Spnd_Per_Bene_2017', 'Outlier_Flag_2017', 'Tot_Spndng_2018',
#            'Tot_Dsg_Unts_2018', 'Tot_Clms_2018', 'Tot_Benes_2018',
#            'Avg_Spnd_Per_Dsg_Unt_Wghtd_2018', 'Avg_Spnd_Per_Clm_2018',
#            'Avg_Spnd_Per_Bene_2018', 'Outlier_Flag_2018', 'Tot_Spndng_2019',
#            'Tot_Dsg_Unts_2019', 'Tot_Clms_2019', 'Tot_Benes_2019',
#            'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019', 'Avg_Spnd_Per_Clm_2019',
#            'Avg_Spnd_Per_Bene_2019', 'Outlier_Flag_2019', 'Tot_Spndng_2020',
#            'Tot_Dsg_Unts_2020', 'Tot_Clms_2020', 'Tot_Benes_2020',
#            'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020', 'Avg_Spnd_Per_Clm_2020',
#            'Avg_Spnd_Per_Bene_2020', 'Outlier_Flag_2020', 'Tot_Spndng_2021',
#            'Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Tot_Benes_2021',
#            'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021', 'Avg_Spnd_Per_Clm_2021',
#            'Avg_Spnd_Per_Bene_2021', 'Outlier_Flag_2021',
#            'Chg_Avg_Spnd_Per_Dsg_Unt_20_21', 'CAGR_Avg_Spnd_Per_Dsg_Unt_17_21'],
#           dtype='object')
#
#
#
#
# ```python
# # look for null values
# medicare.isnull().sum()
# ```
#
#
#
#
#     Brnd_Name                             0
#     Gnrc_Name                             0
#     Tot_Mftr                              0
#     Mftr_Name                             0
#     Tot_Spndng_2017                    4394
#     Tot_Dsg_Unts_2017                  4394
#     Tot_Clms_2017                      4394
#     Tot_Benes_2017                     4462
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    4394
#     Avg_Spnd_Per_Clm_2017              4394
#     Avg_Spnd_Per_Bene_2017             4576
#     Outlier_Flag_2017                  4394
#     Tot_Spndng_2018                    3380
#     Tot_Dsg_Unts_2018                  3380
#     Tot_Clms_2018                      3380
#     Tot_Benes_2018                     3534
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    3380
#     Avg_Spnd_Per_Clm_2018              3380
#     Avg_Spnd_Per_Bene_2018             3587
#     Outlier_Flag_2018                  3380
#     Tot_Spndng_2019                    2270
#     Tot_Dsg_Unts_2019                  2270
#     Tot_Clms_2019                      2270
#     Tot_Benes_2019                     2524
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    2270
#     Avg_Spnd_Per_Clm_2019              2270
#     Avg_Spnd_Per_Bene_2019             2540
#     Outlier_Flag_2019                  2270
#     Tot_Spndng_2020                    1190
#     Tot_Dsg_Unts_2020                  1190
#     Tot_Clms_2020                      1190
#     Tot_Benes_2020                     1566
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2020    1190
#     Avg_Spnd_Per_Clm_2020              1190
#     Avg_Spnd_Per_Bene_2020             1569
#     Outlier_Flag_2020                  1190
#     Tot_Spndng_2021                       0
#     Tot_Dsg_Unts_2021                     0
#     Tot_Clms_2021                         0
#     Tot_Benes_2021                      748
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2021       0
#     Avg_Spnd_Per_Clm_2021                 0
#     Avg_Spnd_Per_Bene_2021              748
#     Outlier_Flag_2021                     0
#     Chg_Avg_Spnd_Per_Dsg_Unt_20_21     1190
#     CAGR_Avg_Spnd_Per_Dsg_Unt_17_21    1086
#     dtype: int64
#
#
#
#
# ```python
# # looking at the unique manufacturers
# medicare['Mftr_Name'].value_counts()
# ```
#
#
#
#
#     Overall             3566
#     Mylan                240
#     Teva USA             236
#     Amneal Pharmace      222
#     Sandoz               221
#                         ...
#     Gsms, Inc.*            1
#     Clover Pharmace        1
#     Ironshore Pharm        1
#     Clarus Therapeu        1
#     Eli Lilly & Co.*       1
#     Name: Mftr_Name, Length: 914, dtype: int64
#
#
#
# Overall here, represents the overall metrics, and is not a Mftr_Name. Hence the data has to be filtere accordingly later on.
#
#
# ```python
# # filtering teh raw dataset for data without Overall metrics
# medicare2 = medicare[medicare['Mftr_Name'] == 'Overall']
# ```
#
#
# ```python
# # creating a new dataset, representing just the diabetes medications
# diabetic_medication = [
#     'glipizide', 'glimepiride', 'glyburide', 'pioglitazone', 'rosiglitazone',
#     'acarbose', 'miglitol', 'tolazamide', 'insulin', 'glyburide-metformin',
#     'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#     'metformin-pioglitazone', 'metformin', 'repaglinide', 'nateglinide',
#     'chlorpropamide', 'troglitazone', 'tolbutamide', 'acetohexamide', 'diabetic'
# ]
#
# # convert the "Brnd_Name" and "Gnrc_Name" column to lowercase
# medicare['Brnd_Name'] = medicare['Brnd_Name'].str.lower()
# medicare['Gnrc_Name'] = medicare['Gnrc_Name'].str.lower()
#
# # create a regular expression pattern to match any of the medication names anywhere in the string
# medication_pattern = '|'.join(fr'.*{medication}.*' for medication in diabetic_medication)
#
# # create a new data frame containing rows with medication names matching the pattern
# diabetic_medications = medicare[
#     medicare['Gnrc_Name'].str.contains(medication_pattern, case=False, na=False) | medicare['Brnd_Name'].str.contains(medication_pattern, case=False, na=False) ]
# ```
#
#
# ```python
# # shape of diabetes specific dataset
# diabetic_medications.shape
# ```
#
#
#     ---------------------------------------------------------------------------
#
#     NameError                                 Traceback (most recent call last)
#
#     <ipython-input-1-8e6942d5c8c0> in <module>
#           1 # shape of diabetes specific dataset
#     ----> 2 diabetic_medications.shape
#
#
#     NameError: name 'diabetic_medications' is not defined
#
#
#
# ```python
# # understanding the diabetes dataset
# diabetic_medications.describe()
# ```
#
#
#
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tot_Mftr</th>
#       <th>Tot_Spndng_2017</th>
#       <th>Tot_Dsg_Unts_2017</th>
#       <th>Tot_Clms_2017</th>
#       <th>Tot_Benes_2017</th>
#       <th>Avg_Spnd_Per_Dsg_Unt_Wghtd_2017</th>
#       <th>Avg_Spnd_Per_Clm_2017</th>
#       <th>Avg_Spnd_Per_Bene_2017</th>
#       <th>Outlier_Flag_2017</th>
#       <th>Tot_Spndng_2018</th>
#       <th>...</th>
#       <th>Tot_Spndng_2021</th>
#       <th>Tot_Dsg_Unts_2021</th>
#       <th>Tot_Clms_2021</th>
#       <th>Tot_Benes_2021</th>
#       <th>Avg_Spnd_Per_Dsg_Unt_Wghtd_2021</th>
#       <th>Avg_Spnd_Per_Clm_2021</th>
#       <th>Avg_Spnd_Per_Bene_2021</th>
#       <th>Outlier_Flag_2021</th>
#       <th>Chg_Avg_Spnd_Per_Dsg_Unt_20_21</th>
#       <th>CAGR_Avg_Spnd_Per_Dsg_Unt_17_21</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>805.000000</td>
#       <td>5.910000e+02</td>
#       <td>5.910000e+02</td>
#       <td>5.910000e+02</td>
#       <td>5.790000e+02</td>
#       <td>591.000000</td>
#       <td>591.000000</td>
#       <td>579.000000</td>
#       <td>591.000000</td>
#       <td>6.470000e+02</td>
#       <td>...</td>
#       <td>8.050000e+02</td>
#       <td>8.050000e+02</td>
#       <td>8.050000e+02</td>
#       <td>7.600000e+02</td>
#       <td>805.000000</td>
#       <td>805.000000</td>
#       <td>760.000000</td>
#       <td>805.000000</td>
#       <td>759.000000</td>
#       <td>762.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1.277019</td>
#       <td>5.357798e+07</td>
#       <td>2.344461e+07</td>
#       <td>2.745032e+05</td>
#       <td>7.336839e+04</td>
#       <td>6.017872</td>
#       <td>230.961660</td>
#       <td>871.180892</td>
#       <td>0.054146</td>
#       <td>5.299162e+07</td>
#       <td>...</td>
#       <td>4.684308e+07</td>
#       <td>2.120852e+07</td>
#       <td>2.061514e+05</td>
#       <td>6.328004e+04</td>
#       <td>12.316546</td>
#       <td>256.205935</td>
#       <td>967.916841</td>
#       <td>0.101863</td>
#       <td>0.018161</td>
#       <td>0.001468</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.745365</td>
#       <td>2.365090e+08</td>
#       <td>1.382148e+08</td>
#       <td>1.243968e+06</td>
#       <td>2.871359e+05</td>
#       <td>14.321820</td>
#       <td>670.463170</td>
#       <td>2506.008858</td>
#       <td>0.226496</td>
#       <td>2.261232e+08</td>
#       <td>...</td>
#       <td>2.175333e+08</td>
#       <td>1.434278e+08</td>
#       <td>1.057356e+06</td>
#       <td>2.844141e+05</td>
#       <td>65.210809</td>
#       <td>547.358716</td>
#       <td>2473.853600</td>
#       <td>0.302657</td>
#       <td>0.158579</td>
#       <td>0.090146</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#       <td>2.271800e+02</td>
#       <td>2.870000e+02</td>
#       <td>1.200000e+01</td>
#       <td>1.100000e+01</td>
#       <td>0.000697</td>
#       <td>0.087388</td>
#       <td>0.218107</td>
#       <td>0.000000</td>
#       <td>5.438000e+01</td>
#       <td>...</td>
#       <td>5.549000e+01</td>
#       <td>2.300000e+01</td>
#       <td>1.100000e+01</td>
#       <td>1.100000e+01</td>
#       <td>0.000216</td>
#       <td>0.035966</td>
#       <td>0.099453</td>
#       <td>0.000000</td>
#       <td>-0.724258</td>
#       <td>-0.543367</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.000000</td>
#       <td>2.657833e+04</td>
#       <td>8.480850e+04</td>
#       <td>9.080000e+02</td>
#       <td>3.935000e+02</td>
#       <td>0.208668</td>
#       <td>20.586667</td>
#       <td>52.960428</td>
#       <td>0.000000</td>
#       <td>2.126832e+04</td>
#       <td>...</td>
#       <td>1.454454e+04</td>
#       <td>2.462900e+04</td>
#       <td>3.620000e+02</td>
#       <td>2.540000e+02</td>
#       <td>0.212261</td>
#       <td>21.933170</td>
#       <td>53.844399</td>
#       <td>0.000000</td>
#       <td>-0.009296</td>
#       <td>-0.014066</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1.000000</td>
#       <td>6.332968e+05</td>
#       <td>6.441460e+05</td>
#       <td>8.595000e+03</td>
#       <td>3.089000e+03</td>
#       <td>0.315212</td>
#       <td>32.241143</td>
#       <td>87.896358</td>
#       <td>0.000000</td>
#       <td>5.083468e+05</td>
#       <td>...</td>
#       <td>3.477869e+05</td>
#       <td>3.496740e+05</td>
#       <td>4.240000e+03</td>
#       <td>2.180500e+03</td>
#       <td>0.343643</td>
#       <td>43.963143</td>
#       <td>110.859775</td>
#       <td>0.000000</td>
#       <td>0.014981</td>
#       <td>0.010631</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.000000</td>
#       <td>7.191104e+06</td>
#       <td>7.414677e+06</td>
#       <td>1.016750e+05</td>
#       <td>3.011700e+04</td>
#       <td>2.097685</td>
#       <td>192.782831</td>
#       <td>661.000612</td>
#       <td>0.000000</td>
#       <td>7.754392e+06</td>
#       <td>...</td>
#       <td>7.802053e+06</td>
#       <td>4.472161e+06</td>
#       <td>6.628000e+04</td>
#       <td>2.245425e+04</td>
#       <td>6.086072</td>
#       <td>274.555853</td>
#       <td>752.185562</td>
#       <td>0.000000</td>
#       <td>0.049253</td>
#       <td>0.040239</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>27.000000</td>
#       <td>2.630786e+09</td>
#       <td>2.957755e+09</td>
#       <td>2.495336e+07</td>
#       <td>5.328012e+06</td>
#       <td>91.136349</td>
#       <td>7616.515067</td>
#       <td>33701.424920</td>
#       <td>1.000000</td>
#       <td>2.370339e+09</td>
#       <td>...</td>
#       <td>2.831447e+09</td>
#       <td>3.435408e+09</td>
#       <td>2.424522e+07</td>
#       <td>5.926550e+06</td>
#       <td>861.707298</td>
#       <td>7742.195413</td>
#       <td>37462.653158</td>
#       <td>1.000000</td>
#       <td>1.692912</td>
#       <td>0.454733</td>
#     </tr>
#   </tbody>
# </table>
# <p>8 rows × 43 columns</p>
# </div>
#
#
#
#
# ```python
# # looking for the null values
# diabetic_medications.isnull().sum()
# ```
#
#
#
#
#     Brnd_Name                            0
#     Gnrc_Name                            0
#     Tot_Mftr                             0
#     Mftr_Name                            0
#     Tot_Spndng_2017                    214
#     Tot_Dsg_Unts_2017                  214
#     Tot_Clms_2017                      214
#     Tot_Benes_2017                     226
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2017    214
#     Avg_Spnd_Per_Clm_2017              214
#     Avg_Spnd_Per_Bene_2017             226
#     Outlier_Flag_2017                  214
#     Tot_Spndng_2018                    158
#     Tot_Dsg_Unts_2018                  158
#     Tot_Clms_2018                      158
#     Tot_Benes_2018                     176
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2018    158
#     Avg_Spnd_Per_Clm_2018              158
#     Avg_Spnd_Per_Bene_2018             176
#     Outlier_Flag_2018                  158
#     Tot_Spndng_2019                    100
#     Tot_Dsg_Unts_2019                  100
#     Tot_Clms_2019                      100
#     Tot_Benes_2019                     117
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2019    100
#     Avg_Spnd_Per_Clm_2019              100
#     Avg_Spnd_Per_Bene_2019             117
#     Outlier_Flag_2019                  100
#     Tot_Spndng_2020                     46
#     Tot_Dsg_Unts_2020                   46
#     Tot_Clms_2020                       46
#     Tot_Benes_2020                      65
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2020     46
#     Avg_Spnd_Per_Clm_2020               46
#     Avg_Spnd_Per_Bene_2020              65
#     Outlier_Flag_2020                   46
#     Tot_Spndng_2021                      0
#     Tot_Dsg_Unts_2021                    0
#     Tot_Clms_2021                        0
#     Tot_Benes_2021                      45
#     Avg_Spnd_Per_Dsg_Unt_Wghtd_2021      0
#     Avg_Spnd_Per_Clm_2021                0
#     Avg_Spnd_Per_Bene_2021              45
#     Outlier_Flag_2021                    0
#     Chg_Avg_Spnd_Per_Dsg_Unt_20_21      46
#     CAGR_Avg_Spnd_Per_Dsg_Unt_17_21     43
#     dtype: int64
#
#
#
# Since we are using majority of metrics from the year of 2021, it does not make sense to drop the rows where unrelated variables are having null values. Hence, we will be cleaning the dataset when needed on a case-by-case basis.
#
# Below, we have dropped columns that are absoulte not use for us in this analysis to resuce the run time, increase storage efficiency and ultimately to remove the noise.
#
#
# ```python
# # list of columns to keep
# columns_to_keep = ['Brnd_Name', 'Gnrc_Name', 'Tot_Mftr', 'Mftr_Name', 'Tot_Spndng_2017', 'Tot_Spndng_2018', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']
#
# # keep only the specified columns
# medicare = medicare[columns_to_keep]
# diabetic_medications = diabetic_medications[columns_to_keep]
# ```
#
#
# ```python
# # splitting the diabetes dataset into two dataset based on "Mftr_Name"
# overall_df = diabetic_medications[diabetic_medications['Mftr_Name'] == 'Overall']
# not_overall = diabetic_medications[diabetic_medications['Mftr_Name'] != 'Overall']
# ```
#
# ** Objective 1 **
#
#
# ```python
# # number of diabetes medication
# db = overall_df.Gnrc_Name.nunique()
# print(f' The number of unique Generic diabetes medications are :{db}')
# ```
#
#      The number of unique Generic diabetes medications are :65
#
#
#
# ```python
# # Identifying the unique genric names and finding the proprotion
# prop = medicare2.Gnrc_Name.nunique() / overall_df.Gnrc_Name.nunique()
# print(f' One out of every {round(prop, 0)} medication is diabetes medication')
# ```
#
#      One out of every 29.0 medication is diabetes medication
#
#
#
# ```python
# #Identifying spending columns
# annual_spending_cols = ['Tot_Spndng_2017', 'Tot_Spndng_2018', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']
# not_overall['Annual_Spending'] = not_overall[annual_spending_cols].sum(axis=1)
#
# # Calculating total and average annual spending for diabetic medications
# annual_spending_totals_not_overall = not_overall[annual_spending_cols].sum()
# average_annual_spending_not_overall = not_overall[annual_spending_cols].mean()
#
# # Plotting the trends
# plt.figure(figsize=(12, 6))
# plt.plot(annual_spending_totals_not_overall.index, annual_spending_totals_not_overall.values, marker='o', label='Total Annual Spending')
# plt.plot(average_annual_spending_not_overall.index, average_annual_spending_not_overall.values, marker='x', label='Average Annual Spending per Drug', color='orange')
# plt.title('Annual Trends in Medicare Part D Spending for Diabetic Medications (2017-2021)')
# plt.xlabel('Year')
# plt.ylabel('Spending Total')
# plt.legend()
# plt.grid(True)
# plt.show()
# ```
#
#     /usr/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       This is separate from the ipykernel package so we can avoid doing imports until
#
#
#
# ![png](output_58_1.png)
#
#
# #### Insights
# At least one out of 29 generic medications is diabetes medication. This is a significant number considering the dataset represents medications for all diseases covered by Part D drugs.
#
# ** Objective 2 **
#
#
# ```python
# # code to identify outliers, credit to Dr.Neha Bhomia whose code is used as a backbone for this.
# def find_and_display_outliers(dataframe, column_name, additional_column):
#     """
#     This function finds and displays the outliers in a specific column of a dataframe using the IQR method.
#     params:
#         - dataframe: pandas DataFrame
#         - column_name: Name of the column for which outliers are to be calculated
#         - additional_column: Additional column to be displayed along with 'Gnrc_Name' and 'Tot_Spndng_2017'
#     returns:
#         - A DataFrame containing 'Gnrc_Name', 'Tot_Spndng_2017', and the specified additional column for rows with outliers
#     """
#     # extracting the specified column
#     pd_object = dataframe[column_name]
#
#     # checking if the column contains numerical data
#     if not pd.api.types.is_numeric_dtype(pd_object):
#         raise ValueError(f"The column '{column_name}' does not contain numerical data.")
#
#     # calculating Q1 (also known as 25th percentile)
#     q1 = pd_object.quantile(0.25)
#
#     # calculating Q3 (also known as 75th percentile)
#     q3 = pd_object.quantile(0.75)
#
#     # calculating the IQR
#     iqr = q3 - q1
#
#     # calculating the upper and lower bounds
#     upper = q3 + 1.5 * iqr
#     lower = q1 - 1.5 * iqr
#
#     # finding the outliers
#     outliers_mask = (pd_object < lower) | (pd_object > upper)
#
#     # extracting the rows with outliers
#     outliers_df = dataframe[outliers_mask][['Gnrc_Name', column_name, additional_column]]
#
#     return outliers_df
# ```
#
#
# ```python
# # Finding outliers for 2021
# outliers_result = find_and_display_outliers(not_overall, 'Tot_Spndng_2021', 'Mftr_Name')
# # percentage of outliers in the year 2021
# perc = (outliers_result.Tot_Spndng_2021.sum()/not_overall.Tot_Spndng_2021.sum()*100).round(2)
# print(f' The percentage of outliers in the entire dataset for diabetes medication is {perc} %.')
# ```
#
#      The percentage of outliers in the entire dataset for diabetes medication is 97.42 %.
#
#
#
# ```python
# # grouping the data and adding up the spending by Manufacturer name
# outliers_result = outliers_result.groupby('Mftr_Name')['Tot_Spndng_2021'].sum()
# # sort the data
# outliers_result = outliers_result.sort_values(ascending=False)
# ```
#
#
# ```python
# # selecting the top 5 results
# top_5_outliers = outliers_result.head(5)
#
# # creating a bar chart
# plt.figure(figsize=(10, 6))
# sns.barplot(x=top_5_outliers.values, y=top_5_outliers.index, palette='viridis')
#
# # labels and title
# plt.xlabel('Total Spending in 2021')
# plt.ylabel('Manufacturer Name')
# plt.title('Top 5 Manufacturers - Total Spending in 2021')
#
# # showing the plot
# plt.show()
# ```
#
#
# ![png](output_64_0.png)
#
#
#
# ```python
# outlier_result = find_and_display_outliers(not_overall, 'Tot_Spndng_2021', 'Mftr_Name')
#
# outlier_result = outlier_result.groupby(['Gnrc_Name', 'Mftr_Name'])['Tot_Spndng_2021'].sum()
# ```
#
#
# ```python
# # reset index to make 'Gnrc_Name' and 'Mftr_Name' columns
# outlier_result = outlier_result.reset_index()
#
# # pivoting the data for the heatmap
# heatmap_data = outlier_result.pivot('Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2021')
#
# # making a heatmap with grid lines
# plt.figure(figsize=(15, 10))
# sns.heatmap(heatmap_data, cmap='plasma', fmt=".2e", linewidths=1, linecolor='white', cbar_kws={'label': 'Total Spending'})
# plt.title('Total Outlier Spending in 2021 - Diabetic Medications')
# plt.xlabel('Manufacturer Name')
# plt.ylabel('Generic Name')
# plt.show()
# ```
#
#
# ![png](output_66_0.png)
#
#
#
# ```python
# # select top N manufacturers and generic names
# top_n = 10
# top_manufacturers = outlier_result.groupby('Mftr_Name')['Tot_Spndng_2021'].sum().nlargest(top_n).index
# top_generic_names = outlier_result.groupby('Gnrc_Name')['Tot_Spndng_2021'].sum().nlargest(top_n).index
#
# # filter data for heatmap
# filtered_heatmap_data = outlier_result[outlier_result['Mftr_Name'].isin(top_manufacturers) & outlier_result['Gnrc_Name'].isin(top_generic_names)]
# pivot_table = filtered_heatmap_data.pivot(index='Gnrc_Name', columns='Mftr_Name', values='Tot_Spndng_2021')
#
# # create the enhanced heatmap
# plt.figure(figsize=(10, 10))
# sns.heatmap(pivot_table, cmap='coolwarm', annot=True, fmt=".2e", linewidths=.5, linecolor='black', cbar_kws={'label': 'Total Spending'})
# plt.title('Top Manufacturers vs Generic Names - Total Spending in 2021')
# plt.show()
# ```
#
#
# ![png](output_67_0.png)
#
#
#
# ```python
# # simplified stacked bar chart for top N generic drugs
# top_n_generic = 5
# top_generic_drugs = outlier_result.groupby('Gnrc_Name')['Tot_Spndng_2021'].sum().nlargest(top_n_generic).index
# filtered_data = outlier_result[outlier_result['Gnrc_Name'].isin(top_generic_drugs)]
#
# # pivot for stacking
# pivot_data = filtered_data.pivot_table(index='Gnrc_Name', columns='Mftr_Name', values='Tot_Spndng_2021', aggfunc='sum', fill_value=0)
#
# # plotting the stacked bar chart
# pivot_data.plot(kind='bar', stacked=True, figsize=(10, 5))
# plt.title('Spending Distribution Across Manufacturers for Top Generic Drugs in 2021')
# plt.ylabel('Total Spending')
# plt.xlabel('Generic Drug Name')
# plt.legend(title='Manufacturer', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.show()
# ```
#
#
# ![png](output_68_0.png)
#
#
# #### Insights
#
# As we see above, **97.42%** of the total spending is on the outliers and hence, this needs to be controlled and checked.
#
# Further looking into reasons behind this, as we can see the **top 5 companies** that are responsible for outlier spending patterns also have a monopoly in the drugs they create and hence charge exceptionally high amounts. This is an opportunity for new pharma companies or pharmaceutical companies finding an opportunity to dive into.
#
# Moreover, insulin is the prime drug for diabetes and also responsible for the most spending within outliers. This si one area to cap the prices within drug category.
#
# Also, Medicare needs to negotiate its terms with these manufacturers in ways using policy reform, negotiating the prices, and leveraging the last customer base they have.
#
# Also, the companies that manufacture outlier drugs at lower costs and fall in the normal range, can be looked into for negotiation and providing them with better incentives.
#
# ** Objective 3 **
#
#
# ```python
# # grouping the data by number of manufacturers
# grouped_data = medicare.groupby('Tot_Mftr')[['Tot_Spndng_2017', 'Tot_Spndng_2018', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']].sum()
#
# # resetting index for better readability
# grouped_data.reset_index(inplace=True)
#
# # displaying a data sample
# grouped_data.head()
# ```
#
#
#
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tot_Mftr</th>
#       <th>Tot_Spndng_2017</th>
#       <th>Tot_Spndng_2018</th>
#       <th>Tot_Spndng_2019</th>
#       <th>Tot_Spndng_2020</th>
#       <th>Tot_Spndng_2021</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2.593351e+11</td>
#       <td>2.887545e+11</td>
#       <td>3.205211e+11</td>
#       <td>3.525113e+11</td>
#       <td>3.872484e+11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>8.396436e+09</td>
#       <td>8.666228e+09</td>
#       <td>8.325500e+09</td>
#       <td>7.706891e+09</td>
#       <td>7.977566e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>6.630960e+08</td>
#       <td>7.050209e+08</td>
#       <td>8.999044e+08</td>
#       <td>9.835676e+08</td>
#       <td>1.153433e+09</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>7.425396e+08</td>
#       <td>7.985095e+08</td>
#       <td>8.335715e+08</td>
#       <td>1.006549e+09</td>
#       <td>1.062382e+09</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>6.052448e+08</td>
#       <td>6.491469e+08</td>
#       <td>6.972064e+08</td>
#       <td>7.861110e+08</td>
#       <td>7.593709e+08</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
#
#
#
# ```python
# # plotting the data
# plt.figure(figsize=(12, 6))
#
# # plotting total spending for each year against the number of manufacturers
# plt.plot(grouped_data['Tot_Mftr'], grouped_data['Tot_Spndng_2017'], label='2017')
# plt.plot(grouped_data['Tot_Mftr'], grouped_data['Tot_Spndng_2018'], label='2018')
# plt.plot(grouped_data['Tot_Mftr'], grouped_data['Tot_Spndng_2019'], label='2019')
# plt.plot(grouped_data['Tot_Mftr'], grouped_data['Tot_Spndng_2020'], label='2020')
# plt.plot(grouped_data['Tot_Mftr'], grouped_data['Tot_Spndng_2021'], label='2021')
#
# # adding titles and labels
# plt.title('Total Drug Spending vs. Number of Manufacturers (2017-2021)')
# plt.xlabel('Number of Manufacturers')
# plt.ylabel('Total Drug Spending (in Billions)')
# plt.legend()
# plt.grid()
#
# # display the plot
# plt.show()
# ```
#
#
# ![png](output_72_0.png)
#
#
# #### Insights
#
# Based on the visualization, it is evident that drugs with manufacturers between 0-3 have higher total spending. Drugs with more than 3 manufacturers have comparatively minimal spending.
#
# ** Allen Flynn highlighted in our presentation a key factor contributing to the dominance of single manufacturers for many medications. This predominance often stems from the fact that the branded drugs are under patent protection. This legal safeguard prevents other manufacturers from producing and introducing competitive equivalents.**
#
# ** Objective 4 **
#
#
# ```python
# # calculating the average spending for each year for diabetic drugs using regex
# avg_spending_diabetic = overall_df.filter(regex='Tot_Spndng_').mean()
#
# # calculating the average spending for each year for the original dataset using regex
# avg_spending_original = medicare2.filter(regex='Tot_Spndng_').mean()
#
# # calculating the percentage
# avg_spending_diabetic/avg_spending_original * 100
# ```
#
#
#
#
#     Tot_Spndng_2017    135.131661
#     Tot_Spndng_2018    130.668295
#     Tot_Spndng_2019    123.802940
#     Tot_Spndng_2020    114.276116
#     Tot_Spndng_2021    107.110665
#     dtype: float64
#
#
#
#
# ```python
# # plotting the data
# plt.figure(figsize=(10, 5))
# plt.plot(avg_spending_diabetic.index.str[-4:], avg_spending_diabetic, label='Diabetic Drugs')
# plt.plot(avg_spending_original.index.str[-4:], avg_spending_original, label='Original Dataset')
# plt.title('Average Spending Trends for Diabetic Drugs vs. Original Dataset (2017-2021)')
# plt.xlabel('Year')
# plt.ylabel('Average Spending')
# plt.legend()
# plt.grid()
# plt.show()
# ```
#
#
# ![png](output_76_0.png)
#
#
#
# ```python
# # create figure and axis for the first dataset
# fig, ax1 = plt.subplots(figsize=(10, 6))
#
# # plotting the average spending for diabetic drugs
# ax1.plot(avg_spending_diabetic.index.str[-4:], avg_spending_diabetic, color='blue', marker='o', label='Diabetic Drugs')
# ax1.set_xlabel('Year')
# ax1.set_ylabel('Average Spending on Diabetic Drugs', color='blue')
# ax1.tick_params(axis='y', labelcolor='blue')
#
# # create another axis for the original dataset
# ax2 = ax1.twinx()
# ax2.plot(avg_spending_original.index.str[-4:], avg_spending_original, color='green', marker='x', label='Original Dataset')
# ax2.set_ylabel('Average Spending on Original Dataset', color='green')
# ax2.tick_params(axis='y', labelcolor='green')
#
# # adding title and legend
# plt.title('Comparison of Average Spending Trends (2017-2021)')
# fig.tight_layout()
# plt.grid()
# plt.show()
#
# ```
#
#
# ![png](output_77_0.png)
#
#
# #### Insights:
#
# We can interpret from the chart that the average spending for the original dataset increases, the average spending for diabetes medications has decreased over time.
# However, it is still significant considering that **although they just form 3.45% of the all the prescription drugs, the average spending still is 135(2017)-107(2021) percent more than that of the overall average spending**.
#
# ** Objective 5**
#
# #### Actionable Insights
# 1. **High Proportion of Diabetes Medication:**
#     - Diabetes medications form a significant part of the Medicare Part D portfolio, about 3.5% of the portfolio is related to diabetes medication, indicating a high prevalence of diabetes among beneficiaries.
# 2. **Outlier Spending on Specific Drugs:**
#     - A small number of drugs and manufacturers are responsible for a disproportionately large share of spending, which can be due to lack of competition or patented formulations.
# 3. **Trend of Increasing Spending:**
#     - Overall spending on diabetic medications has been increasing from 2017-2021.
# 4. **Impact of Monopolistic Practices:**
#     - Certain manufacturers with monopolies over specific drugs tend to increase prices, which contributes to the outlier spending
#
# #### Recommendations for Stakeholders
# 1. **Negotiation of Drug Prices:**
#     - We recommend Medicare negotiate directly with drug manufacturers to secure better prices, specifically for high-cost diabetic medications that are outliers in terms of spending cost.
# 2. **Encourage Generic and Biosimilar Drug Use:**
#     - We recommend Medicare to promote the use of generic and biosimilar versions of expensive diabetic medications to provide a more cost-effective alternative without compromising treatment quality.
# 3. **Implement Price Caps:**
#     - We recommend setting price caps for essential diabetic medications to prevent price gouging and ensure affordability for Medicare beneficiaries.
# 4. **Supporting Pharmaceutical Competition:**
#     - We recommend encouraging competition in the pharmaceutical market, in particular for the drugs that are currently monopolized, which will lower prices and increase access to those diabetic medications.
#
# #### Conclusion
# By implementing these recommendations, stakeholders can take steps towards optimizing drug spending in Medicare Part D program, in particularly medications concerning diabetes. These actions can lead to more sustainable healthcare spending, improved access to necessary medications for Medicare beneficiaries, and overall better health outcomes for individuals with diabetes.

# %% [markdown]
# ## <p style="text-align: center;"> References </p>
#
#
# 1. American Diabetes Association. Economic costs of diabetes in the US in 2017. Diabetes Care. 2018;41(5):917–928.
# 1. Wang Y, Zhang P, Shao H, et al. Medical costs associated with diabetes complications in Medicare beneficiaries aged 65 years or older with type 2 diabetes. Diabetes Care. 2022;45(11):2570-2576.
# 1. Zhuo X, Zhang P, Hoerger TJ. Lifetime direct medical costs of treating type 2 diabetes and diabetic complications. Am J Prev Med. 2013;45(3):253–261.
# 1. CMS dashboard: https://portal.cms.gov/MSTR2021/servlet/mstrWeb?evt=2048001&src=mstrWeb.2048001&documentID=203D830811E7EBD800000080EF356F31&visMode=0&currentViewMedia=1&ru=1&share=1&hiddensections=header%2Cpath%2CdockTop%2CdockLeft%2Cfooter&Server=V343069P&Port=0&Project=OIPDA-BI_Prod&
# 1. Policy changes for contract year 2019
# https://www.cms.gov/newsroom/fact-sheets/cms-finalizes-policy-changes-and-updates-medicare-advantage-and-prescription-drug-benefit-program
# 1. https://www.kff.org/medicare/issue-brief/a-small-number-of-drugs-account-for-a-large-share-of-medicare-part-d-spending/
